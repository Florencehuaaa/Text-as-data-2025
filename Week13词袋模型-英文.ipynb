# %% [markdown]
# # 词袋模型

# %%
import pandas as pd

# 导入数据
file_path = '/Users/huaaa/Desktop/text_analysis_twitter_sample.xlsx'
text_ana = pd.read_excel(file_path)
text_ana = text_ana.drop(['Unnamed: 0'], axis=1)
text_ana.head()  # 显示前几行，确认数据加载成功
# Out:
#     index                  id      screen_name                       time  \
# 0   49374  890587249372524544          auctnr1  2017-07-27T10:58:41-04:00
# 1   83246  899354463055618048    SenatorTester  2017-08-20T15:36:27-04:00
# 2  100988  903272105738985472     KeithRothfus  2017-08-31T11:03:46-04:00
# 3  193395  921001114409021440  HASCRepublicans  2017-10-19T09:12:31-04:00
# 4   12662  884911451449774080    SteveKnight25  2017-07-11T19:05:05-04:00
#
#                                                 link  \
# 0  https://www.twitter.com/Reuters/statuses/89058...
# 1  https://www.twitter.com/SenatorTester/statuses...
# 2  https://www.twitter.com/KeithRothfus/statuses/...
# 3  https://www.twitter.com/HASCRepublicans/status...
# 4  https://www.twitter.com/SteveKnight25/statuses...
#
#                                                 text              source
# 0  RT @Reuters MORE: Top U.S. general says, given...  Twitter for iPhone
# 1  T-minus 2 days until our first-ever Last Best ...  Twitter Web Client
# 2  Please know that help is available. Visit http...  Twitter Web Client
# 3  Literally flying the wings off the A-10 in fig...  Twitter Web Client
# 4  Today the House unanimously passed my bill #HR...  Twitter Web Client

# %%
import re

def preprocess_text(text):
    # 转换为小写
    text = text.lower()   

    # # 移除URL
    text = re.sub(r'http\S+', '', text)
    # # 移除特殊字符和数字
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # # 移除多余的空格
    text = re.sub(r'\s+', ' ', text).strip()
    # 移除停用词
    stop_words = set(['to', 'the', 'on', 'rt','of','in','for','and','with','amp','we','you','is','our','my','this','at','are','be'])
    # print(text)
    text = ' '.join([word for word in text.split() if word not in stop_words])  # 移除停用词
    # print(text)
    
    return text

# %%
text_ana["text"].apply(preprocess_text)
# Out:
# 0      reuters more top us general says given challen...
# 1      tminus days until firstever last best outdoors...
# 2      please know that help available visit or call ...
# 3      literally flying wings off a fight against isi...
# 4      today house unanimously passed bill hr which w...
#                              ...
# 495    great conversation presidential historian mich...
# 496    icymi over weekend jeffflake teams up arizona ...
# 497    one americas most beautiful welcoming communit...
# 498    senatordurbin americans gun owners want backgr...
# 499    vvamerica forevergibill shows just how much ca...
# Name: text, Length: 500, dtype: object

# %%
# len(text_ana)
text_ana.shape
# Out:
# (500, 7)

# %% [markdown]
# ## 构建词袋模型

# %%
from sklearn.feature_extraction.text import CountVectorizer

# 初始化CountVectorizer
vectorizer = CountVectorizer()

# 将文本数据转换为词袋特征矩阵
X = vectorizer.fit_transform(text_ana["text"].apply(preprocess_text))

# 展示特征矩阵的形状
print('词袋特征矩阵的形状:', X.shape)

# 展示词袋模型中的所有特征词
print('特征词列表:', vectorizer.get_feature_names_out()[:100])
# Out:
# 词袋特征矩阵的形状: (500, 3507)
# 特征词列表: ['aapis' 'abandoning' 'abandons' 'abell' 'abetterdeal' 'abilities'
#  'ability' 'able' 'abominable' 'abortion' 'about' 'above' 'absolutely'
#  'abt' 'abuses' 'aca' 'academy' 'accept' 'access' 'accessible'
#  'accomplished' 'accomplishing' 'accomplishment' 'accomplishments'
#  'according' 'accords' 'accountability' 'accountable' 'accusations'
#  'accused' 'aclu' 'across' 'act' 'action' 'active' 'activemanagement'
#  'acts' 'actsavemoms' 'actual' 'actually' 'ad' 'add' 'addiction' 'adding'
#  'additional' 'address' 'adl' 'adldenver' 'admin' 'administration'
#  'admins' 'admiral' 'adoption' 'adults' 'advance' 'advances' 'advancing'
#  'advantage' 'advantagesdisadvantages' 'advise' 'advocacy' 'advocating'
#  'affected' 'affecting' 'afford' 'affront' 'afghanistan' 'africa'
#  'african' 'after' 'afternoon' 'ag' 'again' 'against' 'agatcountry' 'age'
#  'agencies' 'agency' 'agenda' 'agents' 'aggressively' 'aglife' 'ago'
#  'agree' 'agreements' 'agribusiness' 'agriculture' 'aguscipolicy' 'aha'
#  'ahead' 'ai' 'aid' 'aim' 'air' 'airport' 'airract' 'aisle' 'al' 'alabama'
#  'alejarnos']

# %%
len(vectorizer.get_feature_names_out())
# Out:
# 3507

# %%
X
# Out:
# <500x3507 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8032 stored elements in Compressed Sparse Row format>

# %%
list(X.toarray())
# Out:
# [array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 1]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 1, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 1, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 1, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 1, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([1, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 1, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0])]

# %% [markdown]
# ## 词频统计

# %%
# 获取词汇表
feature_words = vectorizer.get_feature_names_out()
feature_words.shape
# Out:
# (3507,)

# %%
X.sum(axis=0).A1
# Out:
# array([1, 1, 1, ..., 1, 2, 1])

# %%
list(zip(feature_words, X.sum(axis=0).A1))
# Out:
# [('aapis', 1),
#  ('abandoning', 1),
#  ('abandons', 1),
#  ('abell', 1),
#  ('abetterdeal', 4),
#  ('abilities', 1),
#  ('ability', 1),
#  ('able', 1),
#  ('abominable', 1),
#  ('abortion', 1),
#  ('about', 26),
#  ('above', 1),
#  ('absolutely', 2),
#  ('abt', 3),
#  ('abuses', 1),
#  ('aca', 4),
#  ('academy', 3),
#  ('accept', 1),
#  ('access', 4),
#  ('accessible', 1),
#  ('accomplished', 2),
#  ('accomplishing', 1),
#  ('accomplishment', 1),
#  ('accomplishments', 1),
#  ('according', 1),
#  ('accords', 1),
#  ('accountability', 1),
#  ('accountable', 2),
#  ('accusations', 1),
#  ('accused', 1),
#  ('aclu', 1),
#  ('across', 4),
#  ('act', 19),
#  ('action', 6),
#  ('active', 1),
#  ('activemanagement', 1),
#  ('acts', 2),
#  ('actsavemoms', 2),
#  ('actual', 1),
#  ('actually', 2),
#  ('ad', 1),
#  ('add', 3),
#  ('addiction', 1),
#  ('adding', 1),
#  ('additional', 1),
#  ('address', 4),
#  ('adl', 1),
#  ('adldenver', 1),
#  ('admin', 4),
#  ('administration', 4),
#  ('admins', 1),
#  ('admiral', 1),
#  ('adoption', 2),
#  ('adults', 1),
#  ('advance', 1),
#  ('advances', 1),
#  ('advancing', 1),
#  ('advantage', 1),
#  ('advantagesdisadvantages', 1),
#  ('advise', 1),
#  ('advocacy', 1),
#  ('advocating', 1),
#  ('affected', 2),
#  ('affecting', 1),
#  ('afford', 3),
#  ('affront', 1),
#  ('afghanistan', 1),
#  ('africa', 1),
#  ('african', 1),
#  ('after', 8),
#  ('afternoon', 4),
#  ('ag', 2),
#  ('again', 3),
#  ('against', 14),
#  ('agatcountry', 1),
#  ('age', 1),
#  ('agencies', 2),
#  ('agency', 3),
#  ('agenda', 3),
#  ('agents', 1),
#  ('aggressively', 1),
#  ('aglife', 1),
#  ('ago', 4),
#  ('agree', 4),
#  ('agreements', 1),
#  ('agribusiness', 1),
#  ('agriculture', 1),
#  ('aguscipolicy', 1),
#  ('aha', 1),
#  ('ahead', 2),
#  ('ai', 1),
#  ('aid', 3),
#  ('aim', 1),
#  ('air', 4),
#  ('airport', 1),
#  ('airract', 2),
#  ('aisle', 1),
#  ('al', 1),
#  ('alabama', 2),
#  ('alejarnos', 1),
#  ('alert', 2),
#  ('alex', 1),
#  ('alexandermurray', 2),
#  ('alfero', 1),
#  ('algop', 1),
#  ('algopintroy', 1),
#  ('all', 30),
#  ('allamericanpetphotoday', 1),
#  ('allen', 1),
#  ('allies', 2),
#  ('allow', 2),
#  ('almost', 2),
#  ('alone', 3),
#  ('along', 2),
#  ('alsen', 1),
#  ('also', 1),
#  ('always', 3),
#  ('am', 17),
#  ('amazing', 2),
#  ('ambassador', 2),
#  ('ambassadors', 1),
#  ('ambiente', 1),
#  ('amcollsurgeons', 1),
#  ('ameadetx', 1),
#  ('amen', 1),
#  ('amendment', 6),
#  ('america', 8),
#  ('american', 16),
#  ('americans', 20),
#  ('americas', 2),
#  ('amicus', 1),
#  ('among', 3),
#  ('amount', 1),
#  ('amt', 1),
#  ('amy', 1),
#  ('an', 27),
#  ('analysis', 1),
#  ('ann', 3),
#  ('anniversary', 4),
#  ('announce', 1),
#  ('announced', 1),
#  ('announces', 1),
#  ('annual', 2),
#  ('another', 1),
#  ('answer', 1),
#  ('answers', 3),
#  ('antarctica', 1),
#  ('anthem', 3),
#  ('antichoice', 1),
#  ('antiimmigrant', 1),
#  ('antilgbt', 1),
#  ('antitrans', 1),
#  ('antiwomen', 1),
#  ('anxious', 1),
#  ('any', 5),
#  ('anything', 2),
#  ('ap', 4),
#  ('apologies', 1),
#  ('app', 3),
#  ('appalling', 1),
#  ('apparent', 1),
#  ('apparently', 2),
#  ('applauds', 1),
#  ('apply', 1),
#  ('appointed', 1),
#  ('appointment', 1),
#  ('appreciate', 3),
#  ('appreciated', 1),
#  ('apprehensions', 1),
#  ('apprenticeship', 1),
#  ('appropriations', 2),
#  ('approps', 1),
#  ('approved', 2),
#  ('aprildryan', 1),
#  ('ar', 1),
#  ('arbitrary', 1),
#  ('are', 48),
#  ('area', 1),
#  ('areas', 1),
#  ('arent', 3),
#  ('argentina', 1),
#  ('argues', 1),
#  ('arguing', 1),
#  ('arizona', 4),
#  ('arizonan', 1),
#  ('arkansans', 1),
#  ('armed', 1),
#  ('army', 2),
#  ('around', 9),
#  ('arpaio', 1),
#  ('arresting', 1),
#  ('arriesgan', 1),
#  ('arrived', 1),
#  ('article', 1),
#  ('artifacts', 1),
#  ('as', 43),
#  ('ashleestrong', 1),
#  ('ask', 1),
#  ('asked', 4),
#  ('assad', 1),
#  ('assassination', 2),
#  ('assault', 2),
#  ('assembly', 1),
#  ('assigned', 1),
#  ('assist', 2),
#  ('assistance', 2),
#  ('assisting', 1),
#  ('association', 1),
#  ('assure', 1),
#  ('astros', 1),
#  ('at', 71),
#  ('atf', 1),
#  ('atr', 2),
#  ('atrocities', 1),
#  ('attack', 6),
#  ('attempt', 1),
#  ('attempting', 1),
#  ('attempts', 1),
#  ('attend', 2),
#  ('attendance', 1),
#  ('attention', 2),
#  ('attorney', 1),
#  ('au', 1),
#  ('aubrey', 1),
#  ('audio', 1),
#  ('aug', 1),
#  ('august', 1),
#  ('australian', 1),
#  ('autauga', 1),
#  ('authorities', 1),
#  ('authority', 1),
#  ('authorization', 1),
#  ('automatic', 3),
#  ('automaticvoterregistration', 1),
#  ('available', 4),
#  ('aviation', 2),
#  ('avoid', 1),
#  ('avr', 1),
#  ('award', 1),
#  ('awarded', 1),
#  ('awards', 1),
#  ('awareness', 1),
#  ('away', 2),
#  ('awesome', 2),
#  ('awful', 2),
#  ('ax', 1),
#  ('azds', 1),
#  ('babies', 1),
#  ('baby', 1),
#  ('back', 13),
#  ('backbone', 1),
#  ('background', 1),
#  ('backyard', 1),
#  ('bad', 6),
#  ('bags', 1),
#  ('baldwin', 1),
#  ('ban', 4),
#  ('bank', 3),
#  ('bankrupt', 1),
#  ('banned', 2),
#  ('bannon', 3),
#  ('bannons', 1),
#  ('baps', 1),
#  ('barbaraannflrn', 1),
#  ('barbaric', 1),
#  ('barcelona', 1),
#  ('barletta', 1),
#  ('barns', 1),
#  ('barrett', 1),
#  ('barring', 1),
#  ('base', 1),
#  ('basketball', 1),
#  ('battle', 2),
#  ('bbq', 1),
#  ('bc', 2),
#  ('be', 49),
#  ('beach', 1),
#  ('beachs', 1),
#  ('bearsears', 1),
#  ('beautiful', 5),
#  ('beavoter', 1),
#  ('because', 5),
#  ('become', 2),
#  ('been', 16),
#  ('before', 3),
#  ('began', 2),
#  ('begin', 1),
#  ('begins', 1),
#  ('begun', 1),
#  ('behalf', 1),
#  ('behavior', 1),
#  ('behind', 2),
#  ('being', 7),
#  ('bekindtoelephants', 1),
#  ('believe', 4),
#  ('believed', 1),
#  ('believes', 1),
#  ('bellcountyh', 1),
#  ('benefit', 2),
#  ('benefits', 3),
#  ('bengoldey', 1),
#  ('benniegthompson', 1),
#  ('bensasse', 3),
#  ('bensasses', 1),
#  ('benyc', 1),
#  ('bertzfredrick', 1),
#  ('beschloss', 1),
#  ('besides', 1),
#  ('best', 6),
#  ('bestowed', 1),
#  ('bet', 1),
#  ('bethanyshondark', 1),
#  ('better', 5),
#  ('beyond', 2),
#  ('biblical', 1),
#  ('big', 4),
#  ('bigbanks', 1),
#  ('bigcats', 1),
#  ('bigger', 1),
#  ('bigoted', 2),
#  ('bigotry', 3),
#  ('bil', 1),
#  ('bill', 27),
#  ('billcassidy', 1),
#  ('billclinton', 1),
#  ('billion', 3),
#  ('billionairesfirst', 2),
#  ('billions', 1),
#  ('bills', 5),
#  ('bipartisan', 10),
#  ('bitcoin', 1),
#  ('biz', 1),
#  ('bizroundtable', 1),
#  ('bklyneagle', 1),
#  ('black', 1),
#  ('blackfact', 1),
#  ('blast', 1),
#  ('blatant', 1),
#  ('blessings', 1),
#  ('blight', 1),
#  ('blitz', 1),
#  ('block', 1),
#  ('blocking', 1),
#  ('blocks', 1),
#  ('blood', 1),
#  ('blow', 1),
#  ('blueprint', 1),
#  ('bluff', 1),
#  ('board', 2),
#  ('boeing', 1),
#  ('book', 2),
#  ('booming', 1),
#  ('boosts', 1),
#  ('booted', 1),
#  ('border', 7),
#  ('borders', 1),
#  ('borderwall', 1),
#  ('both', 2),
#  ('bottom', 2),
#  ('box', 1),
#  ('bpshow', 1),
#  ('bradashford', 1),
#  ('bragged', 1),
#  ('brandontalk', 1),
#  ('brasher', 1),
#  ('brave', 2),
#  ('bravely', 1),
#  ('breach', 1),
#  ('break', 4),
#  ('breakfast', 1),
#  ('breaking', 7),
#  ('breakingthesilence', 1),
#  ('breaks', 2),
#  ('breast', 1),
#  ('breastcancerawareness', 1),
#  ('breathe', 1),
#  ('brewing', 1),
#  ('bribed', 1),
#  ('brief', 1),
#  ('briefing', 1),
#  ('briefs', 1),
#  ('bright', 1),
#  ('brighter', 1),
#  ('bring', 4),
#  ('british', 1),
#  ('broadview', 1),
#  ('broke', 1),
#  ('broken', 1),
#  ('brooklyn', 1),
#  ('brought', 3),
#  ('brown', 1),
#  ('buck', 1),
#  ('budge', 1),
#  ('budget', 10),
#  ('buffalo', 1),
#  ('building', 2),
#  ('bump', 1),
#  ('bunch', 1),
#  ('burlington', 1),
#  ('burma', 2),
#  ('bury', 1),
#  ('buscar', 1),
#  ('business', 4),
#  ('businesses', 4),
#  ('bust', 1),
#  ('but', 9),
#  ('buying', 1),
#  ('bveltrop', 1),
#  ('by', 40),
#  ('bydanaferguson', 1),
#  ('ca', 2),
#  ('cabinet', 3),
#  ('calfire', 1),
#  ('californias', 1),
#  ('call', 10),
#  ('calling', 2),
#  ('calls', 2),
#  ('came', 2),
#  ('campaign', 2),
#  ('can', 18),
#  ('cancel', 1),
#  ('cancer', 1),
#  ('candidate', 1),
#  ('canintl', 1),
#  ('cannot', 4),
#  ('cant', 3),
#  ('cantara', 1),
#  ('capac', 2),
#  ('capital', 2),
#  ('capitol', 3),
#  ('car', 1),
#  ('care', 18),
#  ('career', 1),
#  ('caregivers', 3),
#  ('cares', 1),
#  ('carloslcurbelo', 1),
#  ('carlyle', 1),
#  ('carolhln', 1),
#  ('cartersville', 1),
#  ('case', 2),
#  ('catch', 1),
#  ('catholic', 1),
#  ('cathy', 1),
#  ('cattle', 1),
#  ('caucus', 2),
#  ('cause', 2),
#  ('cbc', 1),
#  ('cblakespear', 1),
#  ('cbo', 1),
#  ('cbsnews', 1),
#  ('cecilerichards', 1),
#  ('cedarridgehigh', 1),
#  ('ceiling', 1),
#  ('celebrate', 3),
#  ('celebratefp', 1),
#  ('celebratethearts', 1),
#  ('celebrating', 2),
#  ('celebration', 1),
#  ('celebrity', 1),
#  ('censuretrump', 1),
#  ('centenariansday', 1),
#  ('center', 4),
#  ('centers', 2),
#  ('central', 1),
#  ('century', 2),
#  ('centurys', 1),
#  ('ceo', 2),
#  ('certainly', 1),
#  ('certainty', 1),
#  ('cfo', 1),
#  ('cfpb', 2),
#  ('chair', 2),
#  ('chairman', 4),
#  ('challenge', 2),
#  ('challenges', 1),
#  ('chance', 2),
#  ('change', 1),
#  ('changes', 3),
#  ('chaos', 1),
#  ('character', 2),
#  ('charge', 1),
#  ('charged', 3),
#  ('charges', 1),
#  ('charitable', 1),
#  ('charleston', 1),
#  ('charlie', 2),
#  ('charlottesville', 5),
#  ('chchope', 1),
#  ('cheap', 2),
#  ('check', 4),
#  ('checks', 1),
#  ('cheers', 1),
#  ('chibokgirls', 1),
#  ('child', 1),
#  ('children', 6),
#  ('chip', 2),
#  ('chm', 1),
#  ('chmn', 1),
#  ('choice', 1),
#  ('chooses', 1),
#  ('christmas', 1),
#  ('chuckgrassley', 1),
#  ('chucktodd', 2),
#  ('chuluotavfw', 1),
#  ('chunk', 1),
#  ('church', 2),
#  ('churches', 1),
#  ('cicilline', 1),
#  ('cicillines', 1),
#  ('circle', 1),
#  ('circuit', 2),
#  ('circumstances', 1),
#  ('cite', 1),
#  ('cities', 4),
#  ('citizens', 3),
#  ('citizenship', 2),
#  ('city', 6),
#  ('cityfillmore', 1),
#  ('cityofencinitas', 1),
#  ('cityofreno', 1),
#  ('civil', 2),
#  ('civilians', 1),
#  ('civility', 1),
#  ('civilityand', 1),
#  ('claims', 2),
#  ('class', 8),
#  ('classes', 2),
#  ('clayton', 1),
#  ('clean', 2),
#  ('cleaning', 1),
#  ('cleansing', 1),
#  ('cleanup', 1),
#  ('clear', 3),
#  ('clearance', 2),
#  ('clearly', 1),
#  ('clevelanddotcom', 1),
#  ('click', 1),
#  ('climate', 1),
#  ('climatechangescientists', 1),
#  ('climatedenier', 1),
#  ('climb', 1),
#  ('clinton', 1),
#  ('clintons', 1),
#  ('clock', 1),
#  ('close', 1),
#  ('closed', 2),
#  ('closely', 1),
#  ('closer', 1),
#  ('closest', 1),
#  ('club', 3),
#  ('cmreynoso', 1),
#  ('cmte', 1),
#  ('cnn', 1),
#  ('cnnnewsroom', 1),
#  ('coal', 2),
#  ('coast', 1),
#  ('coastal', 1),
#  ('coconino', 1),
#  ('code', 8),
#  ('coffee', 1),
#  ('coherent', 1),
#  ('colin', 1),
#  ('collapses', 1),
#  ('colleague', 1),
#  ('colleagues', 9),
#  ('collection', 1),
#  ('collegeforall', 1),
#  ('combatant', 1),
#  ('come', 4),
#  ('comes', 3),
#  ('coming', 3),
#  ('commander', 1),
#  ('commanding', 1),
#  ('commemorating', 1),
#  ('comment', 1),
#  ('comments', 3),
#  ('commercebank', 1),
#  ('commission', 1),
#  ('commissioner', 1),
#  ('commissions', 1),
#  ('commitment', 1),
#  ('committed', 5),
#  ('committee', 11),
#  ('common', 1),
#  ('communities', 9),
#  ('community', 9),
#  ('company', 1),
#  ('comparison', 2),
#  ('competent', 1),
#  ('competition', 2),
#  ('competitiveness', 1),
#  ('complacency', 1),
#  ('completely', 1),
#  ('component', 1),
#  ('computer', 1),
#  ('comunidad', 1),
#  ('concern', 1),
#  ('concerning', 1),
#  ('concerted', 1),
#  ('concluded', 1),
#  ('condemning', 2),
#  ('conditions', 2),
#  ('condolences', 1),
#  ('conduct', 1),
#  ('coney', 1),
#  ('conference', 2),
#  ('confidence', 1),
#  ('confirmation', 2),
#  ('confirmed', 2),
#  ('conflict', 1),
#  ('confronting', 1),
#  ('congratulates', 1),
#  ('congratulations', 2),
#  ('congress', 19),
#  ('congressional', 3),
#  ('congressionalappchallenge', 1),
#  ('congressionalfootballgame', 1),
#  ('congressman', 2),
#  ('congressmangt', 1),
#  ('congressmanhice', 1),
#  ('connected', 1),
#  ('connecting', 1),
#  ('conscious', 1),
#  ('consecuencias', 1),
#  ('consequences', 1),
#  ('consideration', 1),
#  ('considers', 1),
#  ('constituents', 1),
#  ('constitutionctrs', 1),
#  ('constructive', 2),
#  ('consumer', 1),
#  ('consumers', 3),
#  ('contact', 2),
#  ('content', 1),
#  ('contest', 1),
#  ('continue', 5),
#  ('continued', 4),
#  ('continuing', 1),
#  ('contract', 2),
#  ('contracts', 1),
#  ('contribute', 1),
#  ('control', 2),
#  ('convenience', 1),
#  ('conversation', 2),
#  ('conversations', 1),
#  ('convicted', 2),
#  ('cook', 1),
#  ('cool', 1),
#  ('copy', 1),
#  ('corporate', 2),
#  ('corruption', 1),
#  ('corybooker', 1),
#  ('cosponsor', 2),
#  ('cosponsoring', 1),
#  ('cosponsors', 2),
#  ('cost', 1),
#  ('costs', 3),
#  ('costsharing', 2),
#  ('could', 10),
#  ('couldnt', 1),
#  ('councilman', 1),
#  ('councilmember', 1),
#  ('counsel', 2),
#  ('countering', 1),
#  ('counties', 1),
#  ('countless', 1),
#  ('country', 9),
#  ('county', 6),
#  ('courage', 3),
#  ('course', 1),
#  ('court', 2),
#  ('courtesy', 1),
#  ('courtrooms', 1),
#  ('courts', 2),
#  ('cover', 2),
#  ('coverage', 5),
#  ('coveted', 1),
#  ('cowardly', 1),
#  ('cpc', 1),
#  ('cpos', 1),
#  ('cr', 1),
#  ('crash', 1),
#  ('crdova', 1),
#  ('create', 2),
#  ('created', 2),
#  ('creates', 2),
#  ('creating', 1),
#  ('creation', 1),
#  ('credit', 2),
#  ('creedon', 1),
#  ('creek', 1),
#  ('crew', 1),
#  ('criminal', 1),
#  ('criminals', 1),
#  ('crises', 1),
#  ('crisis', 6),
#  ('critical', 3),
#  ('criticism', 3),
#  ('critics', 2),
#  ('crop', 1),
#  ('cross', 1),
#  ('crowd', 1),
#  ('crraidernation', 1),
#  ('cruel', 2),
#  ('cruelty', 1),
#  ('crushing', 2),
#  ('cruz', 1),
#  ('cruzando', 1),
#  ('cryptocurrency', 1),
#  ('cspan', 1),
#  ('ct', 1),
#  ('cuba', 1),
#  ('culprit', 1),
#  ('current', 5),
#  ('currently', 2),
#  ('curtis', 1),
#  ('custody', 1),
#  ('customs', 1),
#  ('cut', 2),
#  ('cuts', 10),
#  ('cutting', 1),
#  ('cybersecurity', 2),
#  ('cynicism', 1),
#  ('daca', 9),
#  ('daily', 1),
#  ('dailycaller', 1),
#  ('dali', 1),
#  ('dam', 1),
#  ('damage', 1),
#  ('dan', 1),
#  ('danger', 2),
#  ('dangerous', 3),
#  ('daniel', 1),
#  ('dark', 1),
#  ('darrellissa', 1),
#  ('data', 2),
#  ('davidwebbshow', 1),
#  ('day', 20),
#  ('days', 3),
#  ('dc', 9),
#  ('dcexaminer', 2),
#  ('dcipalestine', 2),
#  ('dcjobfair', 1),
#  ('ddale', 1),
#  ('de', 3),
#  ('deadline', 3),
#  ('deadly', 1),
#  ('deal', 5),
#  ('dealt', 1),
#  ('dear', 1),
#  ('death', 2),
#  ('deaths', 2),
#  ('debate', 4),
#  ('debrief', 1),
#  ('debt', 4),
#  ('decades', 1),
#  ('december', 2),
#  ('decided', 1),
#  ('decision', 6),
#  ('declare', 1),
#  ('declared', 1),
#  ('decline', 1),
#  ('decorated', 1),
#  ('dedicated', 1),
#  ('dedication', 1),
#  ('deduct', 1),
#  ('deduction', 2),
#  ('deep', 1),
#  ('deepest', 1),
#  ('deeply', 3),
#  ('defeat', 3),
#  ('defeating', 1),
#  ('defend', 2),
#  ('defenddaca', 1),
#  ('defense', 3),
#  ('deficit', 3),
#  ('deficits', 2),
#  ('deflect', 1),
#  ('degree', 1),
#  ('delgiorno', 1),
#  ('delicious', 1),
#  ('delighted', 1),
#  ('deliver', 1),
#  ('delivered', 1),
#  ('delivers', 1),
#  ('delwilber', 1),
#  ('dem', 3),
#  ('demand', 2),
#  ('demanding', 1),
#  ('democracy', 2),
#  ('democracynow', 1),
#  ('democrat', 1),
#  ('democrats', 5),
#  ('dems', 2),
#  ('demsespanol', 2),
#  ('denounce', 1),
#  ('deny', 1),
#  ('departments', 1),
#  ('depend', 1),
#  ('deploy', 1),
#  ('deportation', 2),
#  ('deporting', 1),
#  ('dept', 1),
#  ('deserve', 8),
#  ('deserves', 1),
#  ('desperate', 1),
#  ('desperately', 1),
#  ('despicable', 1),
#  ('destroyed', 1),
#  ('destructive', 1),
#  ('detailed', 1),
#  ('details', 1),
#  ('detained', 1),
#  ('detecting', 1),
#  ('detention', 1),
#  ('devastated', 1),
#  ('devastation', 1),
#  ('develop', 1),
#  ('development', 1),
#  ('devoted', 1),
#  ('dhs', 1),
#  ('dhsgov', 3),
#  ('did', 4),
#  ('didnt', 1),
#  ('difference', 1),
#  ('difficult', 2),
#  ('dignity', 1),
#  ('dignityandjustice', 1),
#  ('dinner', 1),
#  ('dir', 1),
#  ('dire', 1),
#  ('directamente', 1),
#  ('director', 1),
#  ('directors', 1),
#  ('disabled', 3),
#  ('disabling', 1),
#  ('disagree', 1),
#  ('disaster', 4),
#  ('disastrous', 1),
#  ('disclose', 1),
#  ('discriminate', 1),
#  ('discriminated', 1),
#  ('discrimination', 2),
#  ('discuss', 10),
#  ('discusses', 1),
#  ('discussing', 2),
#  ('discussion', 5),
#  ('disgraceful', 1),
#  ('disgusting', 1),
#  ('dismal', 1),
#  ('dismantling', 1),
#  ('disney', 1),
#  ('displaced', 1),
#  ('dispute', 1),
#  ('disregard', 1),
#  ('dist', 1),
#  ('distributing', 1),
#  ('district', 3),
#  ('disturbing', 2),
#  ('diverse', 1),
#  ('diversity', 2),
#  ('division', 1),
#  ('dmi', 1),
#  ('do', 15),
#  ('dobbs', 1),
#  ('doctors', 1),
#  ('documents', 1),
#  ('doddfrank', 1),
#  ('dodging', 1),
#  ('dods', 1),
#  ('doe', 1),
#  ('does', 8),
#  ('doesnt', 1),
#  ('doing', 3),
#  ('doj', 1),
#  ('dollars', 4),
#  ('domestic', 1),
#  ('dominoes', 1),
#  ('donald', 1),
#  ('donate', 2),
#  ('donations', 1),
#  ('done', 10),
#  ('donjbacon', 1),
#  ('donna', 1),
#  ('donnawafb', 1),
#  ('donors', 1),
#  ('dont', 11),
#  ('donuts', 1),
#  ('door', 1),
#  ('doug', 1),
#  ('down', 4),
#  ('downtown', 2),
#  ('downtownreno', 1),
#  ('downtrodden', 1),
#  ('dr', 4),
#  ('drain', 1),
#  ('drained', 1),
#  ('draintheswamp', 1),
#  ('dream', 2),
#  ('dreamact', 5),
#  ('dreamers', 11),
#  ('dressel', 1),
#  ('drinking', 1),
#  ('driver', 1),
#  ('driving', 1),
#  ('drmoore', 1),
#  ('drove', 1),
#  ('drug', 1),
#  ('drugs', 1),
#  ('dshesgreen', 1),
#  ('dts', 1),
#  ('dump', 1),
#  ('during', 10),
#  ('dv', 1),
#  ('dyk', 1),
#  ('dyker', 1),
#  ('each', 2),
#  ('earlier', 1),
#  ('early', 1),
#  ('earn', 1),
#  ('earnhistory', 1),
#  ('earthquake', 1),
#  ('east', 1),
#  ('easy', 3),
#  ('eat', 1),
#  ('econ', 1),
#  ('econjared', 1),
#  ('economa', 1),
#  ('economically', 1),
#  ('economicempowerment', 1),
#  ('economy', 9),
#  ('edisonnj', 1),
#  ('editorial', 1),
#  ('educate', 1),
#  ('education', 4),
#  ('eeuu', 1),
#  ('effect', 1),
#  ('effort', 4),
#  ('efforts', 2),
#  ('ego', 1),
#  ('ehly', 1),
#  ('eitc', 2),
#  ('either', 1),
#  ('el', 2),
#  ('elainaplott', 1),
#  ('elderly', 1),
#  ('election', 2),
#  ('elections', 3),
#  ('electmanka', 1),
#  ('elephants', 1),
#  ('eliminate', 1),
#  ('eliminated', 2),
#  ('eliminating', 1),
#  ('elizabeth', 1),
#  ('elpuentepalante', 1),
#  ('else', 1),
#  ('email', 1),
#  ('emails', 1),
#  ('embarrassingly', 1),
#  ('embrace', 1),
#  ('emerge', 1),
#  ('emergencies', 1),
#  ('emergency', 8),
#  ('emiliotgonzalez', 1),
#  ('employee', 1),
#  ('employers', 1),
#  ('employs', 1),
#  ('empower', 1),
#  ('en', 1),
#  ('enact', 1),
#  ('enacted', 1),
#  ('encinitas', 1),
#  ('encourage', 1),
#  ('encouraged', 1),
#  ('end', 2),
#  ('ending', 1),
#  ('endorse', 1),
#  ('endorsed', 1),
#  ('endorses', 1),
#  ('endorsing', 1),
#  ('enemies', 1),
#  ('enemy', 1),
#  ('energa', 1),
#  ('energy', 4),
#  ('energycommerce', 2),
#  ('enforcement', 1),
#  ('enhance', 1),
#  ('enjoy', 1),
#  ('enjoyed', 2),
#  ('enlightened', 1),
#  ('enough', 3),
#  ('enrollment', 3),
#  ('ensure', 8),
#  ('ensuring', 1),
#  ('entering', 1),
#  ('entire', 2),
#  ('entrepreneurs', 1),
#  ('environment', 5),
#  ('environmental', 1),
#  ('epa', 1),
#  ...]

# %%
# 计算词频统计
word_freq = dict(zip(feature_words, X.sum(axis=0).A1))
word_freq
# Out:
# {'aapis': 1,
#  'abandoning': 1,
#  'abandons': 1,
#  'abell': 1,
#  'abetterdeal': 4,
#  'abilities': 1,
#  'ability': 1,
#  'able': 1,
#  'abominable': 1,
#  'abortion': 1,
#  'about': 26,
#  'above': 1,
#  'absolutely': 2,
#  'abt': 3,
#  'abuses': 1,
#  'aca': 4,
#  'academy': 3,
#  'accept': 1,
#  'access': 4,
#  'accessible': 1,
#  'accomplished': 2,
#  'accomplishing': 1,
#  'accomplishment': 1,
#  'accomplishments': 1,
#  'according': 1,
#  'accords': 1,
#  'accountability': 1,
#  'accountable': 2,
#  'accusations': 1,
#  'accused': 1,
#  'aclu': 1,
#  'across': 4,
#  'act': 19,
#  'action': 6,
#  'active': 1,
#  'activemanagement': 1,
#  'acts': 2,
#  'actsavemoms': 2,
#  'actual': 1,
#  'actually': 2,
#  'ad': 1,
#  'add': 3,
#  'addiction': 1,
#  'adding': 1,
#  'additional': 1,
#  'address': 4,
#  'adl': 1,
#  'adldenver': 1,
#  'admin': 4,
#  'administration': 4,
#  'admins': 1,
#  'admiral': 1,
#  'adoption': 2,
#  'adults': 1,
#  'advance': 1,
#  'advances': 1,
#  'advancing': 1,
#  'advantage': 1,
#  'advantagesdisadvantages': 1,
#  'advise': 1,
#  'advocacy': 1,
#  'advocating': 1,
#  'affected': 2,
#  'affecting': 1,
#  'afford': 3,
#  'affront': 1,
#  'afghanistan': 1,
#  'africa': 1,
#  'african': 1,
#  'after': 8,
#  'afternoon': 4,
#  'ag': 2,
#  'again': 3,
#  'against': 14,
#  'agatcountry': 1,
#  'age': 1,
#  'agencies': 2,
#  'agency': 3,
#  'agenda': 3,
#  'agents': 1,
#  'aggressively': 1,
#  'aglife': 1,
#  'ago': 4,
#  'agree': 4,
#  'agreements': 1,
#  'agribusiness': 1,
#  'agriculture': 1,
#  'aguscipolicy': 1,
#  'aha': 1,
#  'ahead': 2,
#  'ai': 1,
#  'aid': 3,
#  'aim': 1,
#  'air': 4,
#  'airport': 1,
#  'airract': 2,
#  'aisle': 1,
#  'al': 1,
#  'alabama': 2,
#  'alejarnos': 1,
#  'alert': 2,
#  'alex': 1,
#  'alexandermurray': 2,
#  'alfero': 1,
#  'algop': 1,
#  'algopintroy': 1,
#  'all': 30,
#  'allamericanpetphotoday': 1,
#  'allen': 1,
#  'allies': 2,
#  'allow': 2,
#  'almost': 2,
#  'alone': 3,
#  'along': 2,
#  'alsen': 1,
#  'also': 1,
#  'always': 3,
#  'am': 17,
#  'amazing': 2,
#  'ambassador': 2,
#  'ambassadors': 1,
#  'ambiente': 1,
#  'amcollsurgeons': 1,
#  'ameadetx': 1,
#  'amen': 1,
#  'amendment': 6,
#  'america': 8,
#  'american': 16,
#  'americans': 20,
#  'americas': 2,
#  'amicus': 1,
#  'among': 3,
#  'amount': 1,
#  'amt': 1,
#  'amy': 1,
#  'an': 27,
#  'analysis': 1,
#  'ann': 3,
#  'anniversary': 4,
#  'announce': 1,
#  'announced': 1,
#  'announces': 1,
#  'annual': 2,
#  'another': 1,
#  'answer': 1,
#  'answers': 3,
#  'antarctica': 1,
#  'anthem': 3,
#  'antichoice': 1,
#  'antiimmigrant': 1,
#  'antilgbt': 1,
#  'antitrans': 1,
#  'antiwomen': 1,
#  'anxious': 1,
#  'any': 5,
#  'anything': 2,
#  'ap': 4,
#  'apologies': 1,
#  'app': 3,
#  'appalling': 1,
#  'apparent': 1,
#  'apparently': 2,
#  'applauds': 1,
#  'apply': 1,
#  'appointed': 1,
#  'appointment': 1,
#  'appreciate': 3,
#  'appreciated': 1,
#  'apprehensions': 1,
#  'apprenticeship': 1,
#  'appropriations': 2,
#  'approps': 1,
#  'approved': 2,
#  'aprildryan': 1,
#  'ar': 1,
#  'arbitrary': 1,
#  'are': 48,
#  'area': 1,
#  'areas': 1,
#  'arent': 3,
#  'argentina': 1,
#  'argues': 1,
#  'arguing': 1,
#  'arizona': 4,
#  'arizonan': 1,
#  'arkansans': 1,
#  'armed': 1,
#  'army': 2,
#  'around': 9,
#  'arpaio': 1,
#  'arresting': 1,
#  'arriesgan': 1,
#  'arrived': 1,
#  'article': 1,
#  'artifacts': 1,
#  'as': 43,
#  'ashleestrong': 1,
#  'ask': 1,
#  'asked': 4,
#  'assad': 1,
#  'assassination': 2,
#  'assault': 2,
#  'assembly': 1,
#  'assigned': 1,
#  'assist': 2,
#  'assistance': 2,
#  'assisting': 1,
#  'association': 1,
#  'assure': 1,
#  'astros': 1,
#  'at': 71,
#  'atf': 1,
#  'atr': 2,
#  'atrocities': 1,
#  'attack': 6,
#  'attempt': 1,
#  'attempting': 1,
#  'attempts': 1,
#  'attend': 2,
#  'attendance': 1,
#  'attention': 2,
#  'attorney': 1,
#  'au': 1,
#  'aubrey': 1,
#  'audio': 1,
#  'aug': 1,
#  'august': 1,
#  'australian': 1,
#  'autauga': 1,
#  'authorities': 1,
#  'authority': 1,
#  'authorization': 1,
#  'automatic': 3,
#  'automaticvoterregistration': 1,
#  'available': 4,
#  'aviation': 2,
#  'avoid': 1,
#  'avr': 1,
#  'award': 1,
#  'awarded': 1,
#  'awards': 1,
#  'awareness': 1,
#  'away': 2,
#  'awesome': 2,
#  'awful': 2,
#  'ax': 1,
#  'azds': 1,
#  'babies': 1,
#  'baby': 1,
#  'back': 13,
#  'backbone': 1,
#  'background': 1,
#  'backyard': 1,
#  'bad': 6,
#  'bags': 1,
#  'baldwin': 1,
#  'ban': 4,
#  'bank': 3,
#  'bankrupt': 1,
#  'banned': 2,
#  'bannon': 3,
#  'bannons': 1,
#  'baps': 1,
#  'barbaraannflrn': 1,
#  'barbaric': 1,
#  'barcelona': 1,
#  'barletta': 1,
#  'barns': 1,
#  'barrett': 1,
#  'barring': 1,
#  'base': 1,
#  'basketball': 1,
#  'battle': 2,
#  'bbq': 1,
#  'bc': 2,
#  'be': 49,
#  'beach': 1,
#  'beachs': 1,
#  'bearsears': 1,
#  'beautiful': 5,
#  'beavoter': 1,
#  'because': 5,
#  'become': 2,
#  'been': 16,
#  'before': 3,
#  'began': 2,
#  'begin': 1,
#  'begins': 1,
#  'begun': 1,
#  'behalf': 1,
#  'behavior': 1,
#  'behind': 2,
#  'being': 7,
#  'bekindtoelephants': 1,
#  'believe': 4,
#  'believed': 1,
#  'believes': 1,
#  'bellcountyh': 1,
#  'benefit': 2,
#  'benefits': 3,
#  'bengoldey': 1,
#  'benniegthompson': 1,
#  'bensasse': 3,
#  'bensasses': 1,
#  'benyc': 1,
#  'bertzfredrick': 1,
#  'beschloss': 1,
#  'besides': 1,
#  'best': 6,
#  'bestowed': 1,
#  'bet': 1,
#  'bethanyshondark': 1,
#  'better': 5,
#  'beyond': 2,
#  'biblical': 1,
#  'big': 4,
#  'bigbanks': 1,
#  'bigcats': 1,
#  'bigger': 1,
#  'bigoted': 2,
#  'bigotry': 3,
#  'bil': 1,
#  'bill': 27,
#  'billcassidy': 1,
#  'billclinton': 1,
#  'billion': 3,
#  'billionairesfirst': 2,
#  'billions': 1,
#  'bills': 5,
#  'bipartisan': 10,
#  'bitcoin': 1,
#  'biz': 1,
#  'bizroundtable': 1,
#  'bklyneagle': 1,
#  'black': 1,
#  'blackfact': 1,
#  'blast': 1,
#  'blatant': 1,
#  'blessings': 1,
#  'blight': 1,
#  'blitz': 1,
#  'block': 1,
#  'blocking': 1,
#  'blocks': 1,
#  'blood': 1,
#  'blow': 1,
#  'blueprint': 1,
#  'bluff': 1,
#  'board': 2,
#  'boeing': 1,
#  'book': 2,
#  'booming': 1,
#  'boosts': 1,
#  'booted': 1,
#  'border': 7,
#  'borders': 1,
#  'borderwall': 1,
#  'both': 2,
#  'bottom': 2,
#  'box': 1,
#  'bpshow': 1,
#  'bradashford': 1,
#  'bragged': 1,
#  'brandontalk': 1,
#  'brasher': 1,
#  'brave': 2,
#  'bravely': 1,
#  'breach': 1,
#  'break': 4,
#  'breakfast': 1,
#  'breaking': 7,
#  'breakingthesilence': 1,
#  'breaks': 2,
#  'breast': 1,
#  'breastcancerawareness': 1,
#  'breathe': 1,
#  'brewing': 1,
#  'bribed': 1,
#  'brief': 1,
#  'briefing': 1,
#  'briefs': 1,
#  'bright': 1,
#  'brighter': 1,
#  'bring': 4,
#  'british': 1,
#  'broadview': 1,
#  'broke': 1,
#  'broken': 1,
#  'brooklyn': 1,
#  'brought': 3,
#  'brown': 1,
#  'buck': 1,
#  'budge': 1,
#  'budget': 10,
#  'buffalo': 1,
#  'building': 2,
#  'bump': 1,
#  'bunch': 1,
#  'burlington': 1,
#  'burma': 2,
#  'bury': 1,
#  'buscar': 1,
#  'business': 4,
#  'businesses': 4,
#  'bust': 1,
#  'but': 9,
#  'buying': 1,
#  'bveltrop': 1,
#  'by': 40,
#  'bydanaferguson': 1,
#  'ca': 2,
#  'cabinet': 3,
#  'calfire': 1,
#  'californias': 1,
#  'call': 10,
#  'calling': 2,
#  'calls': 2,
#  'came': 2,
#  'campaign': 2,
#  'can': 18,
#  'cancel': 1,
#  'cancer': 1,
#  'candidate': 1,
#  'canintl': 1,
#  'cannot': 4,
#  'cant': 3,
#  'cantara': 1,
#  'capac': 2,
#  'capital': 2,
#  'capitol': 3,
#  'car': 1,
#  'care': 18,
#  'career': 1,
#  'caregivers': 3,
#  'cares': 1,
#  'carloslcurbelo': 1,
#  'carlyle': 1,
#  'carolhln': 1,
#  'cartersville': 1,
#  'case': 2,
#  'catch': 1,
#  'catholic': 1,
#  'cathy': 1,
#  'cattle': 1,
#  'caucus': 2,
#  'cause': 2,
#  'cbc': 1,
#  'cblakespear': 1,
#  'cbo': 1,
#  'cbsnews': 1,
#  'cecilerichards': 1,
#  'cedarridgehigh': 1,
#  'ceiling': 1,
#  'celebrate': 3,
#  'celebratefp': 1,
#  'celebratethearts': 1,
#  'celebrating': 2,
#  'celebration': 1,
#  'celebrity': 1,
#  'censuretrump': 1,
#  'centenariansday': 1,
#  'center': 4,
#  'centers': 2,
#  'central': 1,
#  'century': 2,
#  'centurys': 1,
#  'ceo': 2,
#  'certainly': 1,
#  'certainty': 1,
#  'cfo': 1,
#  'cfpb': 2,
#  'chair': 2,
#  'chairman': 4,
#  'challenge': 2,
#  'challenges': 1,
#  'chance': 2,
#  'change': 1,
#  'changes': 3,
#  'chaos': 1,
#  'character': 2,
#  'charge': 1,
#  'charged': 3,
#  'charges': 1,
#  'charitable': 1,
#  'charleston': 1,
#  'charlie': 2,
#  'charlottesville': 5,
#  'chchope': 1,
#  'cheap': 2,
#  'check': 4,
#  'checks': 1,
#  'cheers': 1,
#  'chibokgirls': 1,
#  'child': 1,
#  'children': 6,
#  'chip': 2,
#  'chm': 1,
#  'chmn': 1,
#  'choice': 1,
#  'chooses': 1,
#  'christmas': 1,
#  'chuckgrassley': 1,
#  'chucktodd': 2,
#  'chuluotavfw': 1,
#  'chunk': 1,
#  'church': 2,
#  'churches': 1,
#  'cicilline': 1,
#  'cicillines': 1,
#  'circle': 1,
#  'circuit': 2,
#  'circumstances': 1,
#  'cite': 1,
#  'cities': 4,
#  'citizens': 3,
#  'citizenship': 2,
#  'city': 6,
#  'cityfillmore': 1,
#  'cityofencinitas': 1,
#  'cityofreno': 1,
#  'civil': 2,
#  'civilians': 1,
#  'civility': 1,
#  'civilityand': 1,
#  'claims': 2,
#  'class': 8,
#  'classes': 2,
#  'clayton': 1,
#  'clean': 2,
#  'cleaning': 1,
#  'cleansing': 1,
#  'cleanup': 1,
#  'clear': 3,
#  'clearance': 2,
#  'clearly': 1,
#  'clevelanddotcom': 1,
#  'click': 1,
#  'climate': 1,
#  'climatechangescientists': 1,
#  'climatedenier': 1,
#  'climb': 1,
#  'clinton': 1,
#  'clintons': 1,
#  'clock': 1,
#  'close': 1,
#  'closed': 2,
#  'closely': 1,
#  'closer': 1,
#  'closest': 1,
#  'club': 3,
#  'cmreynoso': 1,
#  'cmte': 1,
#  'cnn': 1,
#  'cnnnewsroom': 1,
#  'coal': 2,
#  'coast': 1,
#  'coastal': 1,
#  'coconino': 1,
#  'code': 8,
#  'coffee': 1,
#  'coherent': 1,
#  'colin': 1,
#  'collapses': 1,
#  'colleague': 1,
#  'colleagues': 9,
#  'collection': 1,
#  'collegeforall': 1,
#  'combatant': 1,
#  'come': 4,
#  'comes': 3,
#  'coming': 3,
#  'commander': 1,
#  'commanding': 1,
#  'commemorating': 1,
#  'comment': 1,
#  'comments': 3,
#  'commercebank': 1,
#  'commission': 1,
#  'commissioner': 1,
#  'commissions': 1,
#  'commitment': 1,
#  'committed': 5,
#  'committee': 11,
#  'common': 1,
#  'communities': 9,
#  'community': 9,
#  'company': 1,
#  'comparison': 2,
#  'competent': 1,
#  'competition': 2,
#  'competitiveness': 1,
#  'complacency': 1,
#  'completely': 1,
#  'component': 1,
#  'computer': 1,
#  'comunidad': 1,
#  'concern': 1,
#  'concerning': 1,
#  'concerted': 1,
#  'concluded': 1,
#  'condemning': 2,
#  'conditions': 2,
#  'condolences': 1,
#  'conduct': 1,
#  'coney': 1,
#  'conference': 2,
#  'confidence': 1,
#  'confirmation': 2,
#  'confirmed': 2,
#  'conflict': 1,
#  'confronting': 1,
#  'congratulates': 1,
#  'congratulations': 2,
#  'congress': 19,
#  'congressional': 3,
#  'congressionalappchallenge': 1,
#  'congressionalfootballgame': 1,
#  'congressman': 2,
#  'congressmangt': 1,
#  'congressmanhice': 1,
#  'connected': 1,
#  'connecting': 1,
#  'conscious': 1,
#  'consecuencias': 1,
#  'consequences': 1,
#  'consideration': 1,
#  'considers': 1,
#  'constituents': 1,
#  'constitutionctrs': 1,
#  'constructive': 2,
#  'consumer': 1,
#  'consumers': 3,
#  'contact': 2,
#  'content': 1,
#  'contest': 1,
#  'continue': 5,
#  'continued': 4,
#  'continuing': 1,
#  'contract': 2,
#  'contracts': 1,
#  'contribute': 1,
#  'control': 2,
#  'convenience': 1,
#  'conversation': 2,
#  'conversations': 1,
#  'convicted': 2,
#  'cook': 1,
#  'cool': 1,
#  'copy': 1,
#  'corporate': 2,
#  'corruption': 1,
#  'corybooker': 1,
#  'cosponsor': 2,
#  'cosponsoring': 1,
#  'cosponsors': 2,
#  'cost': 1,
#  'costs': 3,
#  'costsharing': 2,
#  'could': 10,
#  'couldnt': 1,
#  'councilman': 1,
#  'councilmember': 1,
#  'counsel': 2,
#  'countering': 1,
#  'counties': 1,
#  'countless': 1,
#  'country': 9,
#  'county': 6,
#  'courage': 3,
#  'course': 1,
#  'court': 2,
#  'courtesy': 1,
#  'courtrooms': 1,
#  'courts': 2,
#  'cover': 2,
#  'coverage': 5,
#  'coveted': 1,
#  'cowardly': 1,
#  'cpc': 1,
#  'cpos': 1,
#  'cr': 1,
#  'crash': 1,
#  'crdova': 1,
#  'create': 2,
#  'created': 2,
#  'creates': 2,
#  'creating': 1,
#  'creation': 1,
#  'credit': 2,
#  'creedon': 1,
#  'creek': 1,
#  'crew': 1,
#  'criminal': 1,
#  'criminals': 1,
#  'crises': 1,
#  'crisis': 6,
#  'critical': 3,
#  'criticism': 3,
#  'critics': 2,
#  'crop': 1,
#  'cross': 1,
#  'crowd': 1,
#  'crraidernation': 1,
#  'cruel': 2,
#  'cruelty': 1,
#  'crushing': 2,
#  'cruz': 1,
#  'cruzando': 1,
#  'cryptocurrency': 1,
#  'cspan': 1,
#  'ct': 1,
#  'cuba': 1,
#  'culprit': 1,
#  'current': 5,
#  'currently': 2,
#  'curtis': 1,
#  'custody': 1,
#  'customs': 1,
#  'cut': 2,
#  'cuts': 10,
#  'cutting': 1,
#  'cybersecurity': 2,
#  'cynicism': 1,
#  'daca': 9,
#  'daily': 1,
#  'dailycaller': 1,
#  'dali': 1,
#  'dam': 1,
#  'damage': 1,
#  'dan': 1,
#  'danger': 2,
#  'dangerous': 3,
#  'daniel': 1,
#  'dark': 1,
#  'darrellissa': 1,
#  'data': 2,
#  'davidwebbshow': 1,
#  'day': 20,
#  'days': 3,
#  'dc': 9,
#  'dcexaminer': 2,
#  'dcipalestine': 2,
#  'dcjobfair': 1,
#  'ddale': 1,
#  'de': 3,
#  'deadline': 3,
#  'deadly': 1,
#  'deal': 5,
#  'dealt': 1,
#  'dear': 1,
#  'death': 2,
#  'deaths': 2,
#  'debate': 4,
#  'debrief': 1,
#  'debt': 4,
#  'decades': 1,
#  'december': 2,
#  'decided': 1,
#  'decision': 6,
#  'declare': 1,
#  'declared': 1,
#  'decline': 1,
#  'decorated': 1,
#  'dedicated': 1,
#  'dedication': 1,
#  'deduct': 1,
#  'deduction': 2,
#  'deep': 1,
#  'deepest': 1,
#  'deeply': 3,
#  'defeat': 3,
#  'defeating': 1,
#  'defend': 2,
#  'defenddaca': 1,
#  'defense': 3,
#  'deficit': 3,
#  'deficits': 2,
#  'deflect': 1,
#  'degree': 1,
#  'delgiorno': 1,
#  'delicious': 1,
#  'delighted': 1,
#  'deliver': 1,
#  'delivered': 1,
#  'delivers': 1,
#  'delwilber': 1,
#  'dem': 3,
#  'demand': 2,
#  'demanding': 1,
#  'democracy': 2,
#  'democracynow': 1,
#  'democrat': 1,
#  'democrats': 5,
#  'dems': 2,
#  'demsespanol': 2,
#  'denounce': 1,
#  'deny': 1,
#  'departments': 1,
#  'depend': 1,
#  'deploy': 1,
#  'deportation': 2,
#  'deporting': 1,
#  'dept': 1,
#  'deserve': 8,
#  'deserves': 1,
#  'desperate': 1,
#  'desperately': 1,
#  'despicable': 1,
#  'destroyed': 1,
#  'destructive': 1,
#  'detailed': 1,
#  'details': 1,
#  'detained': 1,
#  'detecting': 1,
#  'detention': 1,
#  'devastated': 1,
#  'devastation': 1,
#  'develop': 1,
#  'development': 1,
#  'devoted': 1,
#  'dhs': 1,
#  'dhsgov': 3,
#  'did': 4,
#  'didnt': 1,
#  'difference': 1,
#  'difficult': 2,
#  'dignity': 1,
#  'dignityandjustice': 1,
#  'dinner': 1,
#  'dir': 1,
#  'dire': 1,
#  'directamente': 1,
#  'director': 1,
#  'directors': 1,
#  'disabled': 3,
#  'disabling': 1,
#  'disagree': 1,
#  'disaster': 4,
#  'disastrous': 1,
#  'disclose': 1,
#  'discriminate': 1,
#  'discriminated': 1,
#  'discrimination': 2,
#  'discuss': 10,
#  'discusses': 1,
#  'discussing': 2,
#  'discussion': 5,
#  'disgraceful': 1,
#  'disgusting': 1,
#  'dismal': 1,
#  'dismantling': 1,
#  'disney': 1,
#  'displaced': 1,
#  'dispute': 1,
#  'disregard': 1,
#  'dist': 1,
#  'distributing': 1,
#  'district': 3,
#  'disturbing': 2,
#  'diverse': 1,
#  'diversity': 2,
#  'division': 1,
#  'dmi': 1,
#  'do': 15,
#  'dobbs': 1,
#  'doctors': 1,
#  'documents': 1,
#  'doddfrank': 1,
#  'dodging': 1,
#  'dods': 1,
#  'doe': 1,
#  'does': 8,
#  'doesnt': 1,
#  'doing': 3,
#  'doj': 1,
#  'dollars': 4,
#  'domestic': 1,
#  'dominoes': 1,
#  'donald': 1,
#  'donate': 2,
#  'donations': 1,
#  'done': 10,
#  'donjbacon': 1,
#  'donna': 1,
#  'donnawafb': 1,
#  'donors': 1,
#  'dont': 11,
#  'donuts': 1,
#  'door': 1,
#  'doug': 1,
#  'down': 4,
#  'downtown': 2,
#  'downtownreno': 1,
#  'downtrodden': 1,
#  'dr': 4,
#  'drain': 1,
#  'drained': 1,
#  'draintheswamp': 1,
#  'dream': 2,
#  'dreamact': 5,
#  'dreamers': 11,
#  'dressel': 1,
#  'drinking': 1,
#  'driver': 1,
#  'driving': 1,
#  'drmoore': 1,
#  'drove': 1,
#  'drug': 1,
#  'drugs': 1,
#  'dshesgreen': 1,
#  'dts': 1,
#  'dump': 1,
#  'during': 10,
#  'dv': 1,
#  'dyk': 1,
#  'dyker': 1,
#  'each': 2,
#  'earlier': 1,
#  'early': 1,
#  'earn': 1,
#  'earnhistory': 1,
#  'earthquake': 1,
#  'east': 1,
#  'easy': 3,
#  'eat': 1,
#  'econ': 1,
#  'econjared': 1,
#  'economa': 1,
#  'economically': 1,
#  'economicempowerment': 1,
#  'economy': 9,
#  'edisonnj': 1,
#  'editorial': 1,
#  'educate': 1,
#  'education': 4,
#  'eeuu': 1,
#  'effect': 1,
#  'effort': 4,
#  'efforts': 2,
#  'ego': 1,
#  'ehly': 1,
#  'eitc': 2,
#  'either': 1,
#  'el': 2,
#  'elainaplott': 1,
#  'elderly': 1,
#  'election': 2,
#  'elections': 3,
#  'electmanka': 1,
#  'elephants': 1,
#  'eliminate': 1,
#  'eliminated': 2,
#  'eliminating': 1,
#  'elizabeth': 1,
#  'elpuentepalante': 1,
#  'else': 1,
#  'email': 1,
#  'emails': 1,
#  'embarrassingly': 1,
#  'embrace': 1,
#  'emerge': 1,
#  'emergencies': 1,
#  'emergency': 8,
#  'emiliotgonzalez': 1,
#  'employee': 1,
#  'employers': 1,
#  'employs': 1,
#  'empower': 1,
#  'en': 1,
#  'enact': 1,
#  'enacted': 1,
#  'encinitas': 1,
#  'encourage': 1,
#  'encouraged': 1,
#  'end': 2,
#  'ending': 1,
#  'endorse': 1,
#  'endorsed': 1,
#  'endorses': 1,
#  'endorsing': 1,
#  'enemies': 1,
#  'enemy': 1,
#  'energa': 1,
#  'energy': 4,
#  'energycommerce': 2,
#  'enforcement': 1,
#  'enhance': 1,
#  'enjoy': 1,
#  'enjoyed': 2,
#  'enlightened': 1,
#  'enough': 3,
#  'enrollment': 3,
#  'ensure': 8,
#  'ensuring': 1,
#  'entering': 1,
#  'entire': 2,
#  'entrepreneurs': 1,
#  'environment': 5,
#  'environmental': 1,
#  'epa': 1,
#  ...}

# %%
word_freq.items()
# Out:
# dict_items([('aapis', 1), ('abandoning', 1), ('abandons', 1), ('abell', 1), ('abetterdeal', 4), ('abilities', 1), ('ability', 1), ('able', 1), ('abominable', 1), ('abortion', 1), ('about', 26), ('above', 1), ('absolutely', 2), ('abt', 3), ('abuses', 1), ('aca', 4), ('academy', 3), ('accept', 1), ('access', 4), ('accessible', 1), ('accomplished', 2), ('accomplishing', 1), ('accomplishment', 1), ('accomplishments', 1), ('according', 1), ('accords', 1), ('accountability', 1), ('accountable', 2), ('accusations', 1), ('accused', 1), ('aclu', 1), ('across', 4), ('act', 19), ('action', 6), ('active', 1), ('activemanagement', 1), ('acts', 2), ('actsavemoms', 2), ('actual', 1), ('actually', 2), ('ad', 1), ('add', 3), ('addiction', 1), ('adding', 1), ('additional', 1), ('address', 4), ('adl', 1), ('adldenver', 1), ('admin', 4), ('administration', 4), ('admins', 1), ('admiral', 1), ('adoption', 2), ('adults', 1), ('advance', 1), ('advances', 1), ('advancing', 1), ('advantage', 1), ('advantagesdisadvantages', 1), ('advise', 1), ('advocacy', 1), ('advocating', 1), ('affected', 2), ('affecting', 1), ('afford', 3), ('affront', 1), ('afghanistan', 1), ('africa', 1), ('african', 1), ('after', 8), ('afternoon', 4), ('ag', 2), ('again', 3), ('against', 14), ('agatcountry', 1), ('age', 1), ('agencies', 2), ('agency', 3), ('agenda', 3), ('agents', 1), ('aggressively', 1), ('aglife', 1), ('ago', 4), ('agree', 4), ('agreements', 1), ('agribusiness', 1), ('agriculture', 1), ('aguscipolicy', 1), ('aha', 1), ('ahead', 2), ('ai', 1), ('aid', 3), ('aim', 1), ('air', 4), ('airport', 1), ('airract', 2), ('aisle', 1), ('al', 1), ('alabama', 2), ('alejarnos', 1), ('alert', 2), ('alex', 1), ('alexandermurray', 2), ('alfero', 1), ('algop', 1), ('algopintroy', 1), ('all', 30), ('allamericanpetphotoday', 1), ('allen', 1), ('allies', 2), ('allow', 2), ('almost', 2), ('alone', 3), ('along', 2), ('alsen', 1), ('also', 1), ('always', 3), ('am', 17), ('amazing', 2), ('ambassador', 2), ('ambassadors', 1), ('ambiente', 1), ('amcollsurgeons', 1), ('ameadetx', 1), ('amen', 1), ('amendment', 6), ('america', 8), ('american', 16), ('americans', 20), ('americas', 2), ('amicus', 1), ('among', 3), ('amount', 1), ('amt', 1), ('amy', 1), ('an', 27), ('analysis', 1), ('ann', 3), ('anniversary', 4), ('announce', 1), ('announced', 1), ('announces', 1), ('annual', 2), ('another', 1), ('answer', 1), ('answers', 3), ('antarctica', 1), ('anthem', 3), ('antichoice', 1), ('antiimmigrant', 1), ('antilgbt', 1), ('antitrans', 1), ('antiwomen', 1), ('anxious', 1), ('any', 5), ('anything', 2), ('ap', 4), ('apologies', 1), ('app', 3), ('appalling', 1), ('apparent', 1), ('apparently', 2), ('applauds', 1), ('apply', 1), ('appointed', 1), ('appointment', 1), ('appreciate', 3), ('appreciated', 1), ('apprehensions', 1), ('apprenticeship', 1), ('appropriations', 2), ('approps', 1), ('approved', 2), ('aprildryan', 1), ('ar', 1), ('arbitrary', 1), ('are', 48), ('area', 1), ('areas', 1), ('arent', 3), ('argentina', 1), ('argues', 1), ('arguing', 1), ('arizona', 4), ('arizonan', 1), ('arkansans', 1), ('armed', 1), ('army', 2), ('around', 9), ('arpaio', 1), ('arresting', 1), ('arriesgan', 1), ('arrived', 1), ('article', 1), ('artifacts', 1), ('as', 43), ('ashleestrong', 1), ('ask', 1), ('asked', 4), ('assad', 1), ('assassination', 2), ('assault', 2), ('assembly', 1), ('assigned', 1), ('assist', 2), ('assistance', 2), ('assisting', 1), ('association', 1), ('assure', 1), ('astros', 1), ('at', 71), ('atf', 1), ('atr', 2), ('atrocities', 1), ('attack', 6), ('attempt', 1), ('attempting', 1), ('attempts', 1), ('attend', 2), ('attendance', 1), ('attention', 2), ('attorney', 1), ('au', 1), ('aubrey', 1), ('audio', 1), ('aug', 1), ('august', 1), ('australian', 1), ('autauga', 1), ('authorities', 1), ('authority', 1), ('authorization', 1), ('automatic', 3), ('automaticvoterregistration', 1), ('available', 4), ('aviation', 2), ('avoid', 1), ('avr', 1), ('award', 1), ('awarded', 1), ('awards', 1), ('awareness', 1),  ...

# %%
# 观察词袋模型的词频计数结果
sorted(word_freq.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('at', 71),
#  ('qt', 62),
#  ('be', 49),
#  ('are', 48),
#  ('from', 46),
#  ('as', 43),
#  ('it', 43),
#  ('have', 42),
#  ('that', 42),
#  ('by', 40),
#  ('tax', 40),
#  ('who', 38),
#  ('will', 37),
#  ('not', 36),
#  ('trump', 35),
#  ('us', 33),
#  ('today', 32),
#  ('all', 30),
#  ('your', 30),
#  ('here', 29),
#  ('new', 28),
#  ('an', 27),
#  ('bill', 27),
#  ('thank', 27),
#  ('their', 27),
#  ('about', 26),
#  ('more', 26),
#  ('get', 25),
#  ('has', 25),
#  ('need', 25),
#  ('must', 24),
#  ('great', 23),
#  ('help', 23),
#  ('his', 23),
#  ('house', 23),
#  ('im', 23),
#  ('work', 23),
#  ('health', 22),
#  ('its', 22),
#  ('was', 22),
#  ('families', 21),
#  ('he', 21),
#  ('just', 21),
#  ('people', 21),
#  ('what', 21),
#  ('americans', 20),
#  ('day', 20),
#  ('one', 20),
#  ('support', 20),
#  ('they', 20),
#  ('up', 20),
#  ('act', 19),
#  ('congress', 19),
#  ('if', 19),
#  ('live', 19),
#  ('now', 19),
#  ('can', 18),
#  ('care', 18),
#  ('them', 18),
#  ('would', 18),
#  ('am', 17),
#  ('no', 17),
#  ('working', 17),
#  ('american', 16),
#  ('been', 16),
#  ('national', 16),
#  ('out', 16),
#  ('proud', 16),
#  ('senate', 16),
#  ('those', 16),
#  ('do', 15),
#  ('family', 15),
#  ('me', 15),
#  ('when', 15),
#  ('against', 14),
#  ('know', 14),
#  ('rep', 14),
#  ('watch', 14),
#  ('back', 13),
#  ('gop', 13),
#  ('join', 13),
#  ('keep', 13),
#  ('security', 13),
#  ('see', 13),
#  ('thanks', 13),
#  ('time', 13),
#  ('years', 13),
#  ('how', 12),
#  ('like', 12),
#  ('military', 12),
#  ('only', 12),
#  ('or', 12),
#  ('plan', 12),
#  ('potus', 12),
#  ('still', 12),
#  ('year', 12),
#  ('committee', 11),
#  ('dont', 11),
#  ('dreamers', 11),
#  ('every', 11),
#  ('her', 11),
#  ('jobs', 11),
#  ('last', 11),
#  ('make', 11),
#  ('members', 11),
#  ('please', 11),
#  ('reform', 11),
#  ('republicans', 11),
#  ('should', 11),
#  ('state', 11),
#  ('taxreform', 11),
#  ('th', 11),
#  ('these', 11),
#  ('why', 11),
#  ('bipartisan', 10),
#  ('budget', 10),
#  ('call', 10),
#  ('could', 10),
#  ('cuts', 10),
#  ('discuss', 10),
#  ('done', 10),
#  ('during', 10),
#  ('first', 10),
#  ('hearing', 10),
#  ('so', 10),
#  ('take', 10),
#  ('very', 10),
#  ('victims', 10),
#  ('vote', 10),
#  ('want', 10),
#  ('around', 9),
#  ('but', 9),
#  ('colleagues', 9),
#  ('communities', 9),
#  ('community', 9),
#  ('country', 9),
#  ('daca', 9),
#  ('dc', 9),
#  ('economy', 9),
#  ('give', 9),
#  ('group', 9),
#  ('happy', 9),
#  ('him', 9),
#  ('hope', 9),
#  ('important', 9),
#  ('lives', 9),
#  ('morning', 9),
#  ('office', 9),
#  ('over', 9),
#  ('president', 9),
#  ('stand', 9),
#  ('taxes', 9),
#  ('veterans', 9),
#  ('week', 9),
#  ('after', 8),
#  ('america', 8),
#  ('class', 8),
#  ('code', 8),
#  ('deserve', 8),
#  ('does', 8),
#  ('emergency', 8),
#  ('ensure', 8),
#  ('friends', 8),
#  ('going', 8),
#  ('good', 8),
#  ('hard', 8),
#  ('honor', 8),
#  ('pass', 8),
#  ('pm', 8),
#  ('public', 8),
#  ('read', 8),
#  ('safe', 8),
#  ('stop', 8),
#  ('team', 8),
#  ('were', 8),
#  ('women', 8),
#  ('being', 7),
#  ('border', 7),
#  ('breaking', 7),
#  ('icymi', 7),
#  ('introduced', 7),
#  ('job', 7),
#  ('lets', 7),
#  ('life', 7),
#  ('many', 7),
#  ('officials', 7),
#  ('open', 7),
#  ('protect', 7),
#  ('raise', 7),
#  ('realdonaldtrump', 7),
#  ('right', 7),
#  ('said', 7),
#  ('says', 7),
#  ('service', 7),
#  ('she', 7),
#  ('special', 7),
#  ('states', 7),
#  ('students', 7),
#  ('supporting', 7),
#  ('texas', 7),
#  ('than', 7),
#  ('thats', 7),
#  ('there', 7),
#  ('together', 7),
#  ('too', 7),
#  ('tune', 7),
#  ('use', 7),
#  ('washington', 7),
#  ('way', 7),
#  ('wont', 7),
#  ('world', 7),
#  ('youre', 7),
#  ('action', 6),
#  ('amendment', 6),
#  ('attack', 6),
#  ('bad', 6),
#  ('best', 6),
#  ('children', 6),
#  ('city', 6),
#  ('county', 6),
#  ('crisis', 6),
#  ('decision', 6),
#  ('everyone', 6),
#  ('fight', 6),
#  ('funding', 6),
#  ('getting', 6),
#  ('go', 6),
#  ('having', 6),
#  ('issues', 6),
#  ('leaders', 6),
#  ('learn', 6),
#  ('lost', 6),
#  ('meeting', 6),
#  ('member', 6),
#  ('middle', 6),
#  ('million', 6),
#  ('most', 6),
#  ('other', 6),
#  ('own', 6),
#  ('power', 6),
#  ('record', 6),
#  ('resources', 6),
#  ('rights', 6),
#  ('safety', 6),
#  ('some', 6),
#  ('spoke', 6),
#  ('st', 6),
#  ('staff', 6),
#  ('taxpayer', 6),
#  ('todays', 6),
#  ('transgender', 6),
#  ('trumps', 6),
#  ('under', 6),
#  ('va', 6),
#  ('via', 6),
#  ('visit', 6),
#  ('whats', 6),
#  ('white', 6),
#  ('worse', 6),
#  ('wrong', 6),
#  ('yesterday', 6),
#  ('any', 5),
#  ('beautiful', 5),
#  ('because', 5),
#  ('better', 5),
#  ('bills', 5),
#  ('charlottesville', 5),
#  ('committed', 5),
#  ('continue', 5),
#  ('coverage', 5),
#  ('current', 5),
#  ('deal', 5),
#  ('democrats', 5),
#  ('discussion', 5),
#  ('dreamact', 5),
#  ('environment', 5),
#  ('expense', 5),
#  ('floor', 5),
#  ('forward', 5),
#  ('friend', 5),
#  ('given', 5),
#  ('had', 5),
#  ('harvey', 5),
#  ('high', 5),
#  ('higher', 5),
#  ('home', 5),
#  ('hr', 5),
#  ('into', 5),
#  ('investigation', 5),
#  ('issue', 5),
#  ('ive', 5),
#  ('legislation', 5),
#  ('long', 5),
#  ('makes', 5),
#  ('means', 5),
#  ('medicaid', 5),
#  ('money', 5),
#  ('month', 5),
#  ('obamacare', 5),
#  ('off', 5),
#  ('ones', 5),
#  ('opening', 5),
#  ('part', 5),
#  ('passed', 5),
#  ('passing', 5),
#  ('police', 5),
#  ('put', 5),
#  ('recovery', 5),
#  ('reports', 5),
#  ('reproybalallard', 5),
#  ('sanctions', 5),
#  ('senior', 5),
#  ('show', 5),
#  ('statement', 5),
#  ('strong', 5),
#  ('system', 5),
#  ('tech', 5),
#  ('thehill', 5),
#  ('thousands', 5),
#  ('until', 5),
#  ('wealthy', 5),
#  ('where', 5),
#  ('which', 5),
#  ('workers', 5),
#  ('abetterdeal', 4),
#  ('aca', 4),
#  ('access', 4),
#  ('across', 4),
#  ('address', 4),
#  ('admin', 4),
#  ('administration', 4),
#  ('afternoon', 4),
#  ('ago', 4),
#  ('agree', 4),
#  ('air', 4),
#  ('anniversary', 4),
#  ('ap', 4),
#  ('arizona', 4),
#  ('asked', 4),
#  ('available', 4),
#  ('ban', 4),
#  ('believe', 4),
#  ('big', 4),
#  ('break', 4),
#  ('bring', 4),
#  ('business', 4),
#  ('businesses', 4),
#  ('cannot', 4),
#  ('center', 4),
#  ('chairman', 4),
#  ('check', 4),
#  ('cities', 4),
#  ('come', 4),
#  ('continued', 4),
#  ('debate', 4),
#  ('debt', 4),
#  ('did', 4),
#  ('disaster', 4),
#  ('dollars', 4),
#  ('down', 4),
#  ('dr', 4),
#  ('education', 4),
#  ('effort', 4),
#  ('energy', 4),
#  ('equifax', 4),
#  ('everything', 4),
#  ('federal', 4),
#  ('fellow', 4),
#  ('financial', 4),
#  ('fire', 4),
#  ('full', 4),
#  ('future', 4),
#  ('got', 4),
#  ('govt', 4),
#  ('hate', 4),
#  ('healthcare', 4),
#  ('hear', 4),
#  ('housedemocrats', 4),
#  ('housegop', 4),
#  ('improve', 4),
#  ('insurance', 4),
#  ('iran', 4),
#  ('joined', 4),
#  ('law', 4),
#  ('lawmakers', 4),
#  ('let', 4),
#  ('line', 4),
#  ('listen', 4),
#  ('local', 4),
#  ('loved', 4),
#  ('made', 4),
#  ('matter', 4),
#  ('may', 4),
#  ('memorial', 4),
#  ('message', 4),
#  ('months', 4),
#  ('monument', 4),
#  ('much', 4),
#  ('name', 4),
#  ('nation', 4),
#  ('needs', 4),
#  ('never', 4),
#  ('news', 4),
#  ('oped', 4),
#  ('opioid', 4),
#  ('others', 4),
#  ('pay', 4),
#  ('point', 4),
#  ('prayers', 4),
#  ('premiums', 4),
#  ('proposal', 4),
#  ('protectdreamers', 4),
#  ('question', 4),
#  ('realdonaldtrumps', 4),
#  ('relief', 4),
#  ('repcheri', 4),
#  ('repeal', 4),
#  ('russia', 4),
#  ('ryan', 4),
#  ('saturday', 4),
#  ('secretary', 4),
#  ('seniors', 4),
#  ('serve', 4),
#  ('short', 4),
#  ('small', 4),
#  ('spending', 4),
#  ('standing', 4),
#  ('step', 4),
#  ('taking', 4),
#  ('talk', 4),
#  ('thanksgiving', 4),
#  ('things', 4),
#  ('threat', 4),
#  ('through', 4),
#  ('times', 4),
#  ('tomorrow', 4),
#  ('took', 4),
#  ('trumpcare', 4),
#  ('veteran', 4),
#  ('violence', 4),
#  ('voted', 4),
#  ('voting', 4),
#  ('vp', 4),
#  ('water', 4),
#  ('weekend', 4),
#  ('without', 4),
#  ('works', 4),
#  ('york', 4),
#  ('abt', 3),
#  ('academy', 3),
#  ('add', 3),
#  ('afford', 3),
#  ('again', 3),
#  ('agency', 3),
#  ('agenda', 3),
#  ('aid', 3),
#  ('alone', 3),
#  ('always', 3),
#  ('among', 3),
#  ('ann', 3),
#  ('answers', 3),
#  ('anthem', 3),
#  ('app', 3),
#  ('appreciate', 3),
#  ('arent', 3),
#  ('automatic', 3),
#  ('bank', 3),
#  ('bannon', 3),
#  ('before', 3),
#  ('benefits', 3),
#  ('bensasse', 3),
#  ('bigotry', 3),
#  ('billion', 3),
#  ('brought', 3),
#  ('cabinet', 3),
#  ('cant', 3),
#  ('capitol', 3),
#  ('caregivers', 3),
#  ('celebrate', 3),
#  ('changes', 3),
#  ('charged', 3),
#  ('citizens', 3),
#  ('clear', 3),
#  ('club', 3),
#  ('comes', 3),
#  ('coming', 3),
#  ('comments', 3),
#  ('congressional', 3),
#  ('consumers', 3),
#  ('costs', 3),
#  ('courage', 3),
#  ('critical', 3),
#  ('criticism', 3),
#  ('dangerous', 3),
#  ('days', 3),
#  ('de', 3),
#  ('deadline', 3),
#  ('deeply', 3),
#  ('defeat', 3),
#  ('defense', 3),
#  ('deficit', 3),
#  ('dem', 3),
#  ('dhsgov', 3),
#  ('disabled', 3),
#  ('district', 3),
#  ('doing', 3),
#  ('easy', 3),
#  ('elections', 3),
#  ('enough', 3),
#  ('enrollment', 3),
#  ('et', 3),
#  ('excited', 3),
#  ('facebook', 3),
#  ('farm', 3),
#  ('fighting', 3),
#  ('find', 3),
#  ('five', 3),
#  ('follow', 3),
#  ('forest', 3),
#  ('forget', 3),
#  ('former', 3),
#  ('foxnews', 3),
#  ('funeral', 3),
#  ('fy', 3),
#  ('gave', 3),
#  ('general', 3),
#  ('getcovered', 3),
#  ('global', 3),
#  ('goptaxscam', 3),
#  ('government', 3),
#  ('gun', 3),
#  ('half', 3),
#  ('hardworking', 3),
#  ('healthy', 3),
#  ('helped', 3),
#  ('heres', 3),
#  ('homeland', 3),
#  ('hotline', 3),
#  ('hours', 3),
#  ('human', 3),
#  ('hurricane', 3),
#  ('hurricaneirma', 3),
#  ('ice', 3),
#  ('id', 3),
#  ('immediately', 3),
#  ('impact', 3),
#  ('inaction', 3),
#  ('info', 3),
#  ('interest', 3),
#  ('interests', 3),
#  ('irma', 3),
#  ('jeffflake', 3),
#  ('jim', 3),
#  ('john', 3),
#  ('joining', 3),
#  ('key', 3),
#  ('kosovo', 3),
#  ('latest', 3),
#  ('lead', 3),
#  ('leadership', 3),
#  ('legal', 3),
#  ('less', 3),
#  ('letter', 3),
#  ('level', 3),
#  ('look', 3),
#  ('lose', 3),
#  ('major', 3),
#  ('making', 3),
#  ('management', 3),
#  ('mark', 3),
#  ('markup', 3),
#  ('massive', 3),
#  ('maternal', 3),
#  ('mcconnell', 3),
#  ('men', 3),
#  ('might', 3),
#  ('millions', 3),
#  ('mine', 3),
#  ('mr', 3),
#  ('nearly', 3),
#  ('night', 3),
#  ('nsf', 3),
#  ('nws', 3),
#  ('nyc', 3),
#  ('october', 3),
#  ('official', 3),
#  ('old', 3),
#  ('online', 3),
#  ('otd', 3),
#  ('ozone', 3),
#  ('paid', 3),
#  ('para', 3),
#  ('passage', 3),
#  ('piece', 3),
#  ('pleased', 3),
#  ('policy', 3),
#  ('politico', 3),
#  ('pramilajayapal', 3),
#  ('priority', 3),
#  ('program', 3),
#  ('programs', 3),
#  ('protecting', 3),
#  ('protectourcare', 3),
#  ('provide', 3),
#  ('puerto', 3),
#  ('questions', 3),
#  ('ready', 3),
#  ('real', 3),
#  ('reduction', 3),
#  ('release', 3),
#  ('rely', 3),
#  ('remember', 3),
#  ('repgoodlatte', 3),
#  ('repjayapal', 3),
#  ('report', 3),
#  ('republican', 3),
#  ('residents', 3),
#  ('resolution', 3),
#  ('rico', 3),
#  ('ride', 3),
#  ('rohingya', 3),
#  ('round', 3),
#  ('rural', 3),
#  ('russian', 3),
#  ('same', 3),
#  ('sanctuary', 3),
#  ('say', 3),
#  ('school', 3),
#  ('season', 3),
#  ('sen', 3),
#  ('senatemajldr', 3),
#  ('senjohnmccain', 3),
#  ('services', 3),
#  ('shows', 3),
#  ('since', 3),
#  ('socsec', 3),
#  ('soon', 3),
#  ('speak', 3),
#  ('speech', 3),
#  ('starts', 3),
#  ('status', 3),
#  ('stay', 3),
#  ('steve', 3),
#  ('stopped', 3),
#  ('stopping', 3),
#  ('such', 3),
#  ('supreme', 3),
#  ('sure', 3),
#  ('talking', 3),
#  ('thejusticedept', 3),
#  ('three', 3),
#  ('told', 3),
#  ('top', 3),
#  ('toward', 3),
#  ('town', 3),
#  ('tuesday', 3),
#  ('twitter', 3),
#  ('tx', 3),
#  ('understand', 3),
#  ('united', 3),
#  ('uscg', 3),
#  ('used', 3),
#  ('using', 3),
#  ('utpol', 3),
#  ('values', 3),
#  ('veteransday', 3),
#  ('vital', 3),
#  ('voice', 3),
#  ('war', 3),
#  ('well', 3),
#  ('while', 3),
#  ('womens', 3),
#  ('worked', 3),
#  ('wwii', 3),
#  ('young', 3),
#  ('yours', 3),
#  ('absolutely', 2),
#  ('accomplished', 2),
#  ('accountable', 2),
#  ('acts', 2),
#  ('actsavemoms', 2),
#  ('actually', 2),
#  ('adoption', 2),
#  ('affected', 2),
#  ('ag', 2),
#  ('agencies', 2),
#  ('ahead', 2),
#  ('airract', 2),
#  ('alabama', 2),
#  ('alert', 2),
#  ('alexandermurray', 2),
#  ('allies', 2),
#  ('allow', 2),
#  ('almost', 2),
#  ('along', 2),
#  ('amazing', 2),
#  ('ambassador', 2),
#  ('americas', 2),
#  ('annual', 2),
#  ('anything', 2),
#  ('apparently', 2),
#  ('appropriations', 2),
#  ('approved', 2),
#  ('army', 2),
#  ('assassination', 2),
#  ('assault', 2),
#  ('assist', 2),
#  ('assistance', 2),
#  ('atr', 2),
#  ('attend', 2),
#  ('attention', 2),
#  ('aviation', 2),
#  ('away', 2),
#  ('awesome', 2),
#  ('awful', 2),
#  ('banned', 2),
#  ('battle', 2),
#  ('bc', 2),
#  ('become', 2),
#  ('began', 2),
#  ('behind', 2),
#  ('benefit', 2),
#  ('beyond', 2),
#  ('bigoted', 2),
#  ('billionairesfirst', 2),
#  ('board', 2),
#  ('book', 2),
#  ('both', 2),
#  ('bottom', 2),
#  ('brave', 2),
#  ('breaks', 2),
#  ('building', 2),
#  ('burma', 2),
#  ('ca', 2),
#  ('calling', 2),
#  ('calls', 2),
#  ('came', 2),
#  ('campaign', 2),
#  ('capac', 2),
#  ('capital', 2),
#  ('case', 2),
#  ('caucus', 2),
#  ('cause', 2),
#  ('celebrating', 2),
#  ('centers', 2),
#  ('century', 2),
#  ('ceo', 2),
#  ('cfpb', 2),
#  ('chair', 2),
#  ('challenge', 2),
#  ('chance', 2),
#  ('character', 2),
#  ('charlie', 2),
#  ('cheap', 2),
#  ('chip', 2),
#  ('chucktodd', 2),
#  ('church', 2),
#  ('circuit', 2),
#  ('citizenship', 2),
#  ('civil', 2),
#  ('claims', 2),
#  ('classes', 2),
#  ('clean', 2),
#  ('clearance', 2),
#  ('closed', 2),
#  ('coal', 2),
#  ('comparison', 2),
#  ('competition', 2),
#  ('condemning', 2),
#  ('conditions', 2),
#  ('conference', 2),
#  ('confirmation', 2),
#  ('confirmed', 2),
#  ('congratulations', 2),
#  ('congressman', 2),
#  ('constructive', 2),
#  ('contact', 2),
#  ('contract', 2),
#  ('control', 2),
#  ('conversation', 2),
#  ('convicted', 2),
#  ('corporate', 2),
#  ('cosponsor', 2),
#  ('cosponsors', 2),
#  ('costsharing', 2),
#  ('counsel', 2),
#  ('court', 2),
#  ('courts', 2),
#  ('cover', 2),
#  ('create', 2),
#  ('created', 2),
#  ('creates', 2),
#  ('credit', 2),
#  ('critics', 2),
#  ('cruel', 2),
#  ('crushing', 2),
#  ('currently', 2),
#  ('cut', 2),
#  ('cybersecurity', 2),
#  ('danger', 2),
#  ('data', 2),
#  ('dcexaminer', 2),
#  ('dcipalestine', 2),
#  ('death', 2),
#  ('deaths', 2),
#  ('december', 2),
#  ('deduction', 2),
#  ('defend', 2),
#  ('deficits', 2),
#  ('demand', 2),
#  ('democracy', 2),
#  ('dems', 2),
#  ('demsespanol', 2),
#  ('deportation', 2),
#  ('difficult', 2),
#  ('discrimination', 2),
#  ('discussing', 2),
#  ('disturbing', 2),
#  ('diversity', 2),
#  ('donate', 2),
#  ('downtown', 2),
#  ('dream', 2),
#  ('each', 2),
#  ('efforts', 2),
#  ('eitc', 2),
#  ('el', 2),
#  ('election', 2),
#  ('eliminated', 2),
#  ('end', 2),
#  ('energycommerce', 2),
#  ('enjoyed', 2),
#  ('entire', 2),
#  ('epidemic', 2),
#  ('ericschmitt', 2),
#  ('especially', 2),
#  ('esper', 2),
#  ('essential', 2),
#  ('establish', 2),
#  ('estate', 2),
#  ('evacuate', 2),
#  ('evacuation', 2),
#  ('even', 2),
#  ('examine', 2),
#  ('example', 2),
#  ('excellent', 2),
#  ('exec', 2),
#  ('extension', 2),
#  ('faces', 2),
#  ('facing', 2),
#  ('facts', 2),
#  ('falls', 2),
#  ('farms', 2),
#  ('father', 2),
#  ('fdny', 2),
#  ('fema', 2),
#  ('fentanyl', 2),
#  ('fillmore', 2),
#  ('final', 2),
#  ('finalized', 2),
#  ('firstever', 2),
#  ('flight', 2),
#  ('food', 2),
#  ('football', 2),
#  ('force', 2),
#  ('forests', 2),
#  ('foxandfriends', 2),
#  ('foxbusiness', 2),
#  ('free', 2),
#  ('freebeacon', 2),
#  ('freedom', 2),
#  ('freedomcaucus', 2),
#  ('fund', 2),
#  ('funds', 2),
#  ('fwdus', 2),
#  ('gap', 2),
#  ('gas', 2),
#  ('generations', 2),
#  ('gerrymandering', 2),
#  ('gets', 2),
#  ('girls', 2),
#  ('giveaway', 2),
#  ('gives', 2),
#  ('glad', 2),
#  ('golf', 2),
#  ('gopbudget', 2),
#  ('gops', 2),
#  ('gopsenfinance', 2),
#  ('goptaxbill', 2),
#  ('gt', 2),
#  ('gtgt', 2),
#  ('hall', 2),
#  ('happening', 2),
#  ('happythanksgiving', 2),
#  ('harassment', 2),
#  ('hardearned', 2),
#  ('hatred', 2),
#  ('heart', 2),
#  ('heartbreaking', 2),
#  ('helps', 2),
#  ('hes', 2),
#  ('highest', 2),
#  ('hill', 2),
#  ('hispaniccaucus', 2),
#  ('hit', 2),
#  ('hits', 2),
#  ('hold', 2),
#  ('holding', 2),
#  ('holds', 2),
#  ('holiday', 2),
#  ('honored', 2),
#  ('honoring', 2),
#  ('honors', 2),
#  ('hoosier', 2),
#  ('housebudgetgop', 2),
#  ('households', 2),
#  ('idea', 2),
#  ('iii', 2),
#  ('ill', 2),
#  ('immigrants', 2),
#  ('immigration', 2),
#  ('impacted', 2),
#  ('impacts', 2),
#  ('independence', 2),
#  ('indiana', 2),
#  ('innovation', 2),
#  ('inspires', 2),
#  ('interior', 2),
#  ('international', 2),
#  ('internet', 2),
#  ('interns', 2),
#  ('interview', 2),
#  ('introducing', 2),
#  ('irs', 2),
#  ('islands', 2),
#  ('isnt', 2),
#  ('jared', 2),
#  ('joaquincastrotx', 2),
#  ('joe', 2),
#  ('joins', 2),
#  ('joint', 2),
#  ('journalism', 2),
#  ('judiciarydems', 2),
#  ('justice', 2),
#  ('keeping', 2),
#  ('killed', 2),
#  ('kim', 2),
#  ('knock', 2),
#  ('korea', 2),
#  ('kushner', 2),
#  ('lack', 2),
#  ('land', 2),
#  ('launch', 2),
#  ('leave', 2),
#  ('leaving', 2),
#  ('lied', 2),
#  ('ligo', 2),
#  ('list', 2),
#  ('longer', 2),
#  ('looking', 2),
#  ('lot', 2),
#  ('louisiana', 2),
#  ('lower', 2),
#  ('luck', 2),
#  ('majority', 2),
#  ('maternalmortality', 2),
#  ('mattgaetz', 2),
#  ('mayor', 2),
#  ('mean', 2),
#  ('measure', 2),
#  ('medical', 2),
#  ('medicare', 2),
#  ('mehdirhasan', 2),
#  ('met', 2),
#  ('middleclass', 2),
#  ('mike', 2),
#  ('miller', 2),
#  ('mining', 2),
#  ('miss', 2),
#  ('missouri', 2),
#  ('mn', 2),
#  ('mobile', 2),
#  ('moment', 2),
#  ('mt', 2),
#  ('muchneeded', 2),
#  ('mueller', 2),
#  ('multiple', 2),
#  ('museum', 2),
#  ('muslimban', 2),
#  ('nasa', 2),
#  ('nations', 2),
#  ('natl', 2),
#  ('natural', 2),
#  ('nay', 2),
#  ('next', 2),
#  ('nfl', 2),
#  ('nobelprize', 2),
#  ('nominations', 2),
#  ('nominee', 2),
#  ('north', 2),
#  ('nothing', 2),
#  ...]

# %% [markdown]
# ## 词云图

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /opt/anaconda3/lib/python3.10/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /opt/anaconda3/lib/python3.10/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.10/site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.10/site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 根据词袋模型分析结果绘制词云图
wc = WordCloud(
    width=1200, height=800
    , max_words=200
    # , max_font_size=100
    , colormap='Blues'
    , background_color='white'
    , font_path= None
).generate_from_frequencies(word_freq)

# 显示词云图
plt.figure(figsize=(10, 5))
plt.imshow(wc)
plt.axis('off')
# plt.savefig('wordcloud_twi.png', dpi=100)
plt.show()
